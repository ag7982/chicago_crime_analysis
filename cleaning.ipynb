# %% [markdown]
# Loading Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("/Users/asthagupta/Downloads/rbda/Business_Licenses.csv")
data.head()
# Out:
# /Users/asthagupta/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0    16570-20000216       76522           51755            1
# 1    25710-19960216      119268           52896            1
# 2  2712733-20210816     2796409          461483            3
# 3    53383-20150316     2375632           38691            1
# 4  1847540-20090116     1940503           89020           45
#
#                               LEGAL NAME             DOING BUSINESS AS NAME  \
# 0                 THORNDALE CONSTRUCTION             THORNDALE CONSTRUCTION
# 1                      PAT HAMILTON, INC                   PAT HAMILTON CO.
# 2                     J & H DESIGNS INC.                      DCI Furniture
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
snippet = data.head(30)
snippet.to_csv("BLSnippet.csv")

# %%
columns_to_check = ["Block", 'IUCR', 'Primary Type', 'Description', 'Location Description','Location']
for col in columns_to_check:
    print(col)
    data[col] = data[col].str.replace("\"", "'")
    data[col] = data[col].str.replace(',',';')

data.head(50)
# Out:
# Block
# IUCR
# Primary Type
# Description
# Location Description
# Location
#           ID Case Number                    Date                    Block  \
# 0   10224738    HY411648  09/05/2015 01:30:00 PM          043XX S WOOD ST
# 1   10224739    HY411615  09/04/2015 11:30:00 AM      008XX N CENTRAL AVE
# 2   11646166    JC213529  09/01/2018 12:01:00 AM    082XX S INGLESIDE AVE
# 3   10224740    HY411595  09/05/2015 12:45:00 PM        035XX W BARRY AVE
# 4   10224741    HY411610  09/05/2015 01:00:00 PM      0000X N LARAMIE AVE
# 5   10224742    HY411435  09/05/2015 10:55:00 AM      082XX S LOOMIS BLVD
# 6   10224743    HY411629  09/04/2015 06:00:00 PM     021XX W CHURCHILL ST
# 7   10224744    HY411605  09/05/2015 01:00:00 PM        025XX W CERMAK RD
# 8   10224745    HY411654  09/05/2015 11:30:00 AM  031XX W WASHINGTON BLVD
# 9   11645836    JC212333  05/01/2016 12:25:00 AM      055XX S ROCKWELL ST
# 10  10224746    HY411662  09/05/2015 02:00:00 PM       071XX S PULASKI RD
# ...

# %%
data.to_csv("Updated_Crimes.csv", index=False)
